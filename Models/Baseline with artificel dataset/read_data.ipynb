# %%
# !pip install --upgrade -q gspread

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
# Open our new sheet and read some data.
worksheet = gc.open('Namnlöst kalkylark').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
df=pd.DataFrame.from_records(rows)
df.head(n=4)
# Out:
# [['Header ', 'Ingress', 'Text', 'Label'], ['Kommunerna förlorare när staten drar sig tillbaka', 'Får betala priset för haveriet med Arbetsförmedlingen', 'Ni kan historien vid det här laget.\n\nDen moderat-kristdemokratiska servettbudgeten – möjliggjord genom Sverigedemokraternas stöd – skar bort 3,6 miljarder från de arbetsmarknadspolitiska åtgärderna. Sedan kom januariavtalet där Centerpartiet fått igenom en privatisering av Arbetsförmedlingen. Myndigheten ska "reformeras i grunden" och den statliga tjänsten ska ersättas av fristående aktörer.\n\nDals-Ed och Bräcke\nArbetsförmedlingen svarade med att varsla 4 500 anställda och meddela att man stänger 132 av sina 242 arbetsförmedlingskontor. Sedan dess har arbetsmarknadsminister Ylva Johansson, Arbetsförmedlingens generaldirektör Mikael Sjöberg och Centerpartiets arbetsmarknadspolitiska talesperson Martin Ådahl bråkat om vems fel slakten är.\n\nFör ute i verkligheten är det ingen som jublar. Oavsett vad man tycker om hur Arbetsförmedlingen sköter sitt uppdrag är myndighetens närvaro viktig för många svenska kommuner, men ännu mer för arbetssökande och företagare.\n\nOm två år så ska så det nya arbetsförmedlingssystemet sjöstättas. Privata företag tar över och arbetslösa ska äntligen erbjudas valfrihet när de hjälps till jobb.\n\nNu har Ylva Johansson kommit på att det kan bli lite klurigt. Inte bara för att alliansregeringens privatiseringsexperiment gav oss jobbcoacher som med hjälp av healing och beröringsterapi skulle få arbetslösa att rycka upp sig. Nej, risken är att det inte kommer finnas privata företag som är intresserade av att sköta arbetsförmedlandet på orter som Nordmaling, Orsa, Mönsterås, Dals-Ed, Bräcke och Arvidsjaur.  \n\nRussinen ur kakan\nNu kanske statliga Arbetsförmedlingen ändå kommer få finnas kvar som en utförare av arbetsförmedlingstjänster. Annars så får kommunerna hugga i.\nDet budskapet kanske inte är helt välkommet i de svenska kommuner som blir av med Arbetsförmedlingen. Många av dem går redan med underskott och står samtidigt inför en kostnadsexplosion på grund av allt fler av deras medborgare är pensionärer.\n\nMen kanske borde man inte bli förvånad. Det är så här det brukar gå till, och vi känner igen det privatiseringen av bland annat vården och skolan.\n\nDe nya och spännande aktörerna som dyker upp när det gemensamma görs till marknad vill helst inte ha sjuka, svårlärda eller arbetslösa i sitt kundregister eftersom de skattepengar de får för att leverera en tjänst helst ska bli vinst.\n\nDe privata företagen plockar helt enkelt russinen ur kakan och det offentliga får ta kostnaderna för att rädda likvärdigheten.', 'Daniel Swedin'], ['Kristerssons reformer betyder mindre välfärd', 'Oseriöst att kräva sänkta skatter', 'Den här mandatperiodens viktigaste politiska strid kan komma att handla om skattesystemet.\n\nI januariavtalet – överenskommelsen mellan Socialdemokraterna, Miljöpartiet, Centerpartiet och Liberalerna – utlovas en omfattande skattereform, och det finns skäl att jubla över det. Det svenska skattesystemet är ett oöverskådligt lapptäcke som präglas av allt fler specialregler och undantag. \n\nSkatter påverkar\nMen skattesystemet måste inte bara reformeras för enhetlighetens skull. Skatter och hur de är konstruerade påverkar faktiskt samhällsutvecklingen.\n\nDet där begriper förstås Moderaterna. I går meddelade partiet därför att man villkorar sin eventuella medverkan i  skattereformen. Villkoren är klassiskt moderat politik: skattekvoten ska ned, inkomstskatterna ska sänkas, marginalskatten också. Men att höja bolags- eller kapitalskatterna blir det inte tal om. \n\nDäremot kan Moderaterna man tänka sig att ”överväga” höjda miljöskatter, men det blir absolut inga skatter på elektronik, kläder, flygresor eller höjd bensinskatt. \n\nKrävs pengar\nI praktiken ser en moderat skattereform alltså ut att bara innehålla sänkta skatter – på allt. \n\nHär kanske man bör stanna upp och betänka att anledningen till att stat och kommuner tar ut ...
#                                                    0  \
# 0                                            Header
# 1  Kommunerna förlorare när staten drar sig tillbaka
# 2       Kristerssons reformer betyder mindre välfärd
# 3       I spansk politik finns bara ytterkanter kvar
#
#                                                    1  \
# 0                                            Ingress
# 1  Får betala priset för haveriet med Arbetsförme...
# 2                  Oseriöst att kräva sänkta skatter
# 3             Spanskt val kommer inte reda ut kaoset
#
#                                                    2              3
# 0                                               Text          Label
# 1  Ni kan historien vid det här laget.\n\nDen mod...  Daniel Swedin
# 2  Den här mandatperiodens viktigaste politiska s...  Daniel Swedin
# 3  Under det gångna decenniet har Spanien framstå...  Daniel Swedin

# %%
df.columns = df.iloc[0]
df=df.drop([0])
df.head(n=5)
# Out:
# 0                                            Header   \
# 1  Kommunerna förlorare när staten drar sig tillbaka
# 2       Kristerssons reformer betyder mindre välfärd
# 3       I spansk politik finns bara ytterkanter kvar
# 4       I spansk politik finns bara ytterkanter kvar
# 5          Alex & Sigges lyxliv verkar vara känsligt
#
# 0                                            Ingress  \
# 1  Får betala priset för haveriet med Arbetsförme...
# 2                  Oseriöst att kräva sänkta skatter
# 3             Spanskt val kommer inte reda ut kaoset
# 4             Spanskt val kommer inte reda ut kaoset
# 5             Klasshatet har fått en klimatdimension
#
# 0                                               Text          Label
# 1  Ni kan historien vid det här laget.\n\nDen mod...  Daniel Swedin
# 2  Den här mandatperiodens viktigaste politiska s...  Daniel Swedin
# 3  Under det gångna decenniet har Spanien framstå...  Daniel Swedin
# 4  Under det gångna decenniet har Spanien framstå...  Daniel Swedin
# 5  När Malin Persson Giolito skulle skriva sin fj...     Jonna Sima

# %%
df['Text'][1]
# Out:
# 'Ni kan historien vid det här laget.\n\nDen moderat-kristdemokratiska servettbudgeten – möjliggjord genom Sverigedemokraternas stöd – skar bort 3,6 miljarder från de arbetsmarknadspolitiska åtgärderna. Sedan kom januariavtalet där Centerpartiet fått igenom en privatisering av Arbetsförmedlingen. Myndigheten ska "reformeras i grunden" och den statliga tjänsten ska ersättas av fristående aktörer.\n\nDals-Ed och Bräcke\nArbetsförmedlingen svarade med att varsla 4 500 anställda och meddela att man stänger 132 av sina 242 arbetsförmedlingskontor. Sedan dess har arbetsmarknadsminister Ylva Johansson, Arbetsförmedlingens generaldirektör Mikael Sjöberg och Centerpartiets arbetsmarknadspolitiska talesperson Martin Ådahl bråkat om vems fel slakten är.\n\nFör ute i verkligheten är det ingen som jublar. Oavsett vad man tycker om hur Arbetsförmedlingen sköter sitt uppdrag är myndighetens närvaro viktig för många svenska kommuner, men ännu mer för arbetssökande och företagare.\n\nOm två år så ska så det nya arbetsförmedlingssystemet sjöstättas. Privata företag tar över och arbetslösa ska äntligen erbjudas valfrihet när de hjälps till jobb.\n\nNu har Ylva Johansson kommit på att det kan bli lite klurigt. Inte bara för att alliansregeringens privatiseringsexperiment gav oss jobbcoacher som med hjälp av healing och beröringsterapi skulle få arbetslösa att rycka upp sig. Nej, risken är att det inte kommer finnas privata företag som är intresserade av att sköta arbetsförmedlandet på orter som Nordmaling, Orsa, Mönsterås, Dals-Ed, Bräcke och Arvidsjaur.  \n\nRussinen ur kakan\nNu kanske statliga Arbetsförmedlingen ändå kommer få finnas kvar som en utförare av arbetsförmedlingstjänster. Annars så får kommunerna hugga i.\nDet budskapet kanske inte är helt välkommet i de svenska kommuner som blir av med Arbetsförmedlingen. Många av dem går redan med underskott och står samtidigt inför en kostnadsexplosion på grund av allt fler av deras medborgare är pensionärer.\n\nMen kanske borde man inte bli förvånad. Det är så här det brukar gå till, och vi känner igen det privatiseringen av bland annat vården och skolan.\n\nDe nya och spännande aktörerna som dyker upp när det gemensamma görs till marknad vill helst inte ha sjuka, svårlärda eller arbetslösa i sitt kundregister eftersom de skattepengar de får för att leverera en tjänst helst ska bli vinst.\n\nDe privata företagen plockar helt enkelt russinen ur kakan och det offentliga får ta kostnaderna för att rädda likvärdigheten.'

# %%
dfDummies = pd.get_dummies(df['Label'])
df = pd.concat([df, dfDummies], axis=1)

# %%
df.head(n=4)
# Out:
#                                              Header   \
# 1  Kommunerna förlorare när staten drar sig tillbaka
# 2       Kristerssons reformer betyder mindre välfärd
# 3       I spansk politik finns bara ytterkanter kvar
# 4       I spansk politik finns bara ytterkanter kvar
#
#                                              Ingress  \
# 1  Får betala priset för haveriet med Arbetsförme...
# 2                  Oseriöst att kräva sänkta skatter
# 3             Spanskt val kommer inte reda ut kaoset
# 4             Spanskt val kommer inte reda ut kaoset
#
#                                                 Text          Label  \
# 1  Ni kan historien vid det här laget.\n\nDen mod...  Daniel Swedin
# 2  Den här mandatperiodens viktigaste politiska s...  Daniel Swedin
# 3  Under det gångna decenniet har Spanien framstå...  Daniel Swedin
# 4  Under det gångna decenniet har Spanien framstå...  Daniel Swedin
#
#    Anders Lindberg  Daniel Swedin  Jonna Sima
# 1                0              1           0
# 2                0              1           0
# 3                0              1           0
# 4                0              1           0

# %%
df=df.drop('Label',axis=1)
df.head(n=4)
# Out:
#                                              Header   \
# 1  Kommunerna förlorare när staten drar sig tillbaka
# 2       Kristerssons reformer betyder mindre välfärd
# 3       I spansk politik finns bara ytterkanter kvar
# 4       I spansk politik finns bara ytterkanter kvar
#
#                                              Ingress  \
# 1  Får betala priset för haveriet med Arbetsförme...
# 2                  Oseriöst att kräva sänkta skatter
# 3             Spanskt val kommer inte reda ut kaoset
# 4             Spanskt val kommer inte reda ut kaoset
#
#                                                 Text  Anders Lindberg  \
# 1  Ni kan historien vid det här laget.\n\nDen mod...                0
# 2  Den här mandatperiodens viktigaste politiska s...                0
# 3  Under det gångna decenniet har Spanien framstå...                0
# 4  Under det gångna decenniet har Spanien framstå...                0
#
#    Daniel Swedin  Jonna Sima
# 1              1           0
# 2              1           0
# 3              1           0
# 4              1           0
